# %% [markdown]
# ## KNN Handwriting Classification

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
data = np.load('../Day_6/datasets/mnist_train_small.npy')

# %%
data
# Out:
# array([[5, 0, 0, ..., 0, 0, 0],
#        [7, 0, 0, ..., 0, 0, 0],
#        [9, 0, 0, ..., 0, 0, 0],
#        ...,
#        [2, 0, 0, ..., 0, 0, 0],
#        [9, 0, 0, ..., 0, 0, 0],
#        [5, 0, 0, ..., 0, 0, 0]], dtype=uint8)

# %%
X = data[:,1:]
y = data[:,0]

# %%
X.shape, y.shape
# Out:
# ((19999, 784), (19999,))

# %%
X_train, X_test, y_train, y_test = train_test_split(
...     X, y, test_size=0.33, random_state=42)

# %%
model = KNeighborsClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
model.predict(X_test[:10])
# Out:
# array([1, 7, 0, 9, 4, 5, 4, 6, 9, 2], dtype=uint8)

# %%
y_test[:10]
# Out:
# array([7, 7, 0, 9, 4, 5, 4, 6, 9, 2], dtype=uint8)

# %%
# model.score(X_test,y_test) 0.954
model.score(X_test[:100],y_test[:100])
# Out:
# 0.95

# %%
plt.imshow(X_test[0].reshape(28,28), cmap='gray')

# %% [markdown]
# ## Non-Linearly Separable data

# %%
from sklearn.datasets import make_circles

# %%
# make_circles(
#    n_samples=100,
#    noise=None,
#    random_state=None,
#)
# 
# MAkes a large circle containing smaller circle in 2d
X, y = make_circles(n_samples=500)

# %%
# X contains the coordinates (or features) and y contain the label (or class) corresponding to that point
# 500 examples and 2 features
X.shape, y.shape
# Out:
# ((500, 2), (500,))

# %%
# No noise currently
plt.scatter(X[:,0], X[:,1], c=y)
plt.show()

# %%
X, y = make_circles(n_samples=500, noise=0.02)
plt.scatter(X[:,0], X[:,1], c=y)
plt.show()

# %% [markdown]
# #### Applying Logistic Regression to this data

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X,y)
# Out:
# LogisticRegression()

# %%
model.score(X,y)
# Out:
# 0.498

# %% [markdown]
# ## Creating new dimension

# %%
def dim(X):
    X1 = X[:,0]
    X2 = X[:,1]
    # X3 is value for third dimension, can do anything
    X3 = X1**2 + X2**2
    # Previously each example had 2 features X1 and X2; (in 2D)
    # Now, we want each exammple to have 3 features, X1, X2, X3; (in 3d)
    # No of features = no of dimensions
    
    # new X ; no of rows remain same.; no of column = no of features =3
    # zeros(shape, dtype=float, order='C')
    # Return a new array of given shape and type, filled with zeros.
    X_ = np.zeros((X.shape[0], 3))
    # all rows and all columns except last column 
    X_[:,:-1] = X
    # all rows and last column
    X_[:,-1] = X3
    
    return X_

# %%
X_ = dim(X)

# %%
X_.shape
# Out:
# (500, 3)

# %%
X_[:10]
# Out:
# array([[ 0.16635272, -0.97542801,  0.97913303],
#        [-0.5811186 , -0.52529943,  0.61363831],
#        [-0.75888479, -0.25122368,  0.63901947],
#        [-0.21612457,  0.78440943,  0.66200798],
#        [ 0.39051807,  0.7152819 ,  0.66413256],
#        [ 0.20283057,  0.81949878,  0.71271849],
#        [ 0.75787523,  0.65560498,  1.00419275],
#        [ 0.43404379, -0.87586716,  0.9555373 ],
#        [ 0.70860083, -0.67916311,  0.96337767],
#        [-0.91092483, -0.38196332,  0.97568002]])

# %%
X[:10]
# Out:
# array([[ 0.16635272, -0.97542801],
#        [-0.5811186 , -0.52529943],
#        [-0.75888479, -0.25122368],
#        [-0.21612457,  0.78440943],
#        [ 0.39051807,  0.7152819 ],
#        [ 0.20283057,  0.81949878],
#        [ 0.75787523,  0.65560498],
#        [ 0.43404379, -0.87586716],
#        [ 0.70860083, -0.67916311],
#        [-0.91092483, -0.38196332]])

# %% [markdown]
# #### Plot 3d data

# %%
# Part of matplotlib
from mpl_toolkits.mplot3d import Axes3D

# %%
def plot3d(X, show=True):
    # The purpose of using plt.figure() is to create a figure object.
    # The whole figure is regarded as the figure object. It is necessary to explicitly use plt.figure() 
    # when we want to tweak the size of the figure and when we want to add multiple Axes objects in a single figure.
    fig = plt.figure(figsize=(10,10))
    # An Axes3D object is created just like any other axes using the projection=‘3d’ keyword.
    # The default mode for matplotlib is to produce 2D plots. The option projection 
    # becomes available after import Axes3D from mpl_toolkits as the base _axes object will be added.
    # https://matplotlib.org/mpl_toolkits/mplot3d/tutorial.html#getting-started
    ax = fig.add_subplot(111,projection='3d')
    X1 = X[:,0]
    X2 = X[:,1]
    X3 = X[:,2]
    
    # (Position of data points: X1,X2,X3, s=size of points)
    ax.scatter(X1,X2,X3,zdir='z',s=20,c=y,depthshade=True)
    if(show==True):
        plt.show()
    return ax

# %%
ax = plot3d(X_)

# %%
model = LogisticRegression()
model.fit(X_,y)
model.score(X_,y)
# Out:
# 1.0

# %% [markdown]
# #### Visualize Decision Boundary

# %%
wts = model.coef_
bias = model.intercept_

# %%
wts
# Out:
# array([[  0.01524399,   0.06515499, -10.93959055]])

# %%
bias
# Out:
# array([8.97138209])

# %%
# https://stackoverflow.com/questions/36013063/what-is-the-purpose-of-meshgrid-in-python-numpy
xx,yy = np.meshgrid(range(-1,2),range(-1,2))
print(xx)
print(yy)
# Out:
# [[-1  0  1]
#  [-1  0  1]
#  [-1  0  1]]
# [[-1 -1 -1]
#  [ 0  0  0]
#  [ 1  1  1]]

# %%
z = -(wts[0,0]*xx + wts[0,1]*yy+bias)/wts[0,2]
print(z)
# Out:
# [[0.81273454 0.81412801 0.81552148]
#  [0.81869043 0.8200839  0.82147737]
#  [0.82464632 0.82603979 0.82743326]]

# %%
ax = plot3d(X_, show=False)
ax.plot_surface(xx,yy,z,alpha=0.2)
plt.show()

# %% [markdown]
# ### Kernel Based Classification in SVM

# %% [markdown]
# Sklearn supports the following types of Kernels, which can be used in many-real life problems.
#
# 1. Linear Kernel
# 2. RBF Kernel
# 3. Polynomial Kernel
# 4. Sigmoid Kernel
#
# Kernel trick is method of using a linear classifer to solve a non-linear problem. It transforms the linearly in-separable data into linearly separable one.

# %%
from sklearn import svm

# %% [markdown]
# #### Linear Kernel SVM

# %%
# By default, 'RBF' kernel
svc = svm.SVC(kernel="linear")

# %%
svc.fit(X,y)
# Out:
# SVC(kernel='linear')

# %%
svc.score(X,y)
# Out:
# 0.508

# %% [markdown]
# #### RBF Kernel SVM

# %%
svc = svm.SVC(kernel="rbf")
svc.fit(X,y)
svc.score(X,y)
# Out:
# 1.0

# %% [markdown]
# #### Polynomial Kernel SVM

# %%
svc = svm.SVC(kernel="poly")
svc.fit(X,y)
svc.score(X,y)
# Out:
# 0.618

# %% [markdown]
# #### Custom Kernel

# %%
def custom_kernel(x1,x2):
    return np.square(np.dot(x1,x2.T))

svc = svm.SVC(kernel=custom_kernel)
svc.fit(X,y)
svc.score(X,y)
# Out:
# 1.0
