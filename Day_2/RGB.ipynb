# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil=Image.open("RGB.png")

# %%
pil
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=640x480 at 0x1B793D7E148>

# %%
arr=np.array(pil)

# %%
arr.shape
# Out:
# (480, 640, 3)

# %%
red=arr[:,:,0]

# %%
plt.imshow(red)

# %%
green=arr[:,:,1]
plt.imshow(green)

# %%
blue=arr[:,:,2]
plt.imshow(blue)

# %%
#first is the column and second is row, third is depth
part=arr[200:420,0:320,0]
plt.imshow(part)

# %%
redtwo=arr.copy()
redtwo[:,:,[1,2]]=0
plt.imshow(redtwo)

# %%
bluetwo=arr.copy()
bluetwo[:,:,[0,1]]=0
plt.imshow(bluetwo)

# %%
greentwo=arr.copy()
greentwo[:,:,[0,2]]=0
plt.imshow(greentwo)
